# %%
import numpy as np
a = np.array([1, 2, 3])
b = np.array([1, 0, 1])

# %%
a + 2
# Out:
# array([3, 4, 5])

# %%
a - 2
# Out:
# array([-1,  0,  1])

# %%
a * 2
# Out:
# array([2, 4, 6])

# %%
a / 2
# Out:
# array([0.5, 1. , 1.5])

# %%
a + b
# Out:
# array([2, 2, 4])

# %%
a ** 2
# Out:
# array([1, 4, 9])

# %%
np.sin(a)
# Out:
# array([0.84147098, 0.90929743, 0.14112001])

# %%
np.cos(a)
# Out:
# array([ 0.54030231, -0.41614684, -0.9899925 ])
